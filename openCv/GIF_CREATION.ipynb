# %%
import cv2
import numpy as np
import imageio

# %%
# M.L

img1 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img1, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img1, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img1, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img1, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img1, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img1, (90,155),(155,163),(0,0,255),2)
tri1= cv2.drawContours(img1, [triangle_cnt], 0, (0,255,0), 3)
tri2= cv2.drawContours(img1, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img1, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img1, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img1, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img1, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img1, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img1,(250,225), (250,150), (0,0,255),3)
text1= cv2.putText(img1, "Hello Deep Learning",(250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img1, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)



cv2.imshow("Black",img1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img2 = np.zeros((500,500,3), np.int8)



pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])



cir1 = cv2.circle(img2, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img2, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img2, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img2, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img2, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img2, (90,155),(155,163),(0,0,255),3)
tri1= cv2.drawContours(img2, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img2, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img2, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img2, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img2, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img2, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img2, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img2,(250,225), (250,150), (0,0,255),3)
text = cv2.putText(img2, "Hello Machine Learning", (250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img2, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)




cv2.imshow("Black",img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img3 = np.zeros((500,500,3), np.int8)



pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])



cir1 = cv2.circle(img3, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img3, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img3, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img3, (85,67),4,(0,255,0),2)
cir5 = cv2.circle(img3, (177,67),4,(0,255,0),2)
hor = cv2.rectangle(img3, (90,155),(155,163),(0,0,255),3)
tri1= cv2.drawContours(img3, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img3, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img3, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img3, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img3, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img3, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img3, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img3,(250,225), (250,80), (0,0,255),3)
line7 = cv2.line(img3, (250,80), (200,60), (0,0,255),3)

text = cv2.putText(img3, "Why are you so dull ??", (200,50),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img3, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


cv2.imshow("Black",img3)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img4 = np.zeros((500,500,3), np.int8)

cir1 = cv2.circle(img4, (100,100),100,(255,0,0),3)
cir2 = cv2.circle(img4, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img4, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img4, (85,67),4,(0,255,0),2)
cir5 = cv2.circle(img4, (177,67),4,(0,255,0),2)
hor = cv2.rectangle(img4, (90,155),(155,163),(0,0,255),3)
cir6 = cv2.circle(img4, (125,250),100,(255,0,0),3)



line1 = cv2.line(img4, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img4, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img4, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img4, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img4, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img4,(250,225), (250,80), (0,0,255),3)
line7 = cv2.line(img4, (250,80), (200,60), (0,0,255),3)

text = cv2.putText(img4, "I'm Hungry of Data??", (200,50),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img4, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


cv2.imshow("Black",img4)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img5 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img5, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img5, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img5, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img5, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img5, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img5, (90,155),(155,163),(0,0,255),2)
tri1= cv2.drawContours(img5, [triangle_cnt], 0, (0,255,0), 3)
tri2= cv2.drawContours(img5, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img5, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img5, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img5, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img5, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img5, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img5,(250,225), (350,300), (0,0,255),3)
text1= cv2.putText(img5, "Dont worry dear !",(250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text3=cv2.putText(img5," we have enough data",(220,170),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img5, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)



cv2.imshow("Black",img5)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img6 = np.zeros((500,500,3), np.int8)

cir1 = cv2.circle(img6, (90,90),60,(255,0,0),3)
# cir2 = cv2.circle(img6, (80,75),15,(0,0,255),3)
# cir3= cv2.circle(img6, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img6, (65,67),4,(0,255,0),2)
cir5 = cv2.circle(img6, (130,67),4,(0,255,0),2)
# # hor = cv2.rectangle(img6, (90,155),(155,163),(0,0,255),3)
cir6 = cv2.circle(img6, (125,250),100,(255,0,0),3)



line1 = cv2.line(img6, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img6, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img6, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img6, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img6, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img6,(250,225), (250,80), (0,0,255),3)
# line7 = cv2.line(img6, (250,80), (200,60), (0,0,255),3)

text = cv2.putText(img6, "Ohh really im happy then....", (200,100),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img6, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

pt1 = (90,80)
pt2 = (80, 100)
pt3 = (110,100)
triangle_cnt = np.array( [pt1, pt2, pt3] )

tri2= cv2.drawContours(img6, [triangle_cnt], 0, (0,255,0), -1)


cv2.imshow("Black",img6)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img7 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img7, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img7, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img7, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img7, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img7, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img7, (90,155),(155,163),(0,0,255),1)
tri1= cv2.drawContours(img7, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img7, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img7, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img7, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img7, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img7, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img7, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img7,(250,225), (250,150), (0,0,255),3)
text1= cv2.putText(img7,"But you know what ?",(250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text3=cv2.putText(img7,"I can work for small data",(220,400),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img7, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)



cv2.imshow("Black",img7)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img8 = np.zeros((500,500,3), np.int8)

cir1 = cv2.circle(img8, (90,90),60,(255,0,0),3)
# cir2 = cv2.circle(img6, (80,75),15,(0,0,255),3)
# cir3= cv2.circle(img6, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img8, (65,67),4,(0,255,0),2)
cir5 = cv2.circle(img8, (130,67),4,(0,255,0),2)
# # hor = cv2.rectangle(img6, (90,155),(155,163),(0,0,255),3)
cir6 = cv2.circle(img8, (125,250),100,(255,0,0),3)



line1 = cv2.line(img8, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img8, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img8, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img8, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img8, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img6,(250,225), (250,80), (0,0,255),3)
# line7 = cv2.line(img6, (250,80), (200,60), (0,0,255),3)

text = cv2.putText(img8, "Thats interesting  !!!", (200,100),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img8, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

pt1 = (90,80)
pt2 = (80, 100)
pt3 = (110,100)
triangle_cnt = np.array( [pt1, pt2, pt3] )

tri2= cv2.drawContours(img8, [triangle_cnt], 0, (0,255,0), -1)


cv2.imshow("Black",img8)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img9 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img9, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img9, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img9, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img9, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img9, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img9, (90,155),(155,163),(0,0,255),1)
tri1= cv2.drawContours(img9, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img9, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img9, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img9, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img9, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img9, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img9, (125,225), (250,225), (0,0,255),3)
line7 = cv2.line(img9, (125,225), (10,300), (0,0,255),3)
line6 = cv2.line(img9,(250,225), (190,320), (0,0,255),3)
text1= cv2.putText(img9,"Hmm,That is me",(250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text3=cv2.putText(img7,"I can work for small data",(220,400),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img9, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)



cv2.imshow("Black",img9)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img10 = np.zeros((500,500,3), np.int8)



pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])



cir1 = cv2.circle(img10, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img10, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img10, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img10, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img10, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img10, (90,155),(155,163),(0,0,255),3)
tri1= cv2.drawContours(img10, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img10, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img10, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img10, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img10, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img10, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img10, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img10,(250,225), (250,150), (0,0,255),3)
text = cv2.putText(img10, "What about the feature ", (250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text = cv2.putText(img10, "engeneering ?", (250,170),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img10, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)



cv2.imshow("Black",img10)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img11 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img11, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img11, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img11, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img11, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img11, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img11, (90,155),(155,163),(0,0,255),2)
tri1= cv2.drawContours(img11, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img11, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img11, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img11, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img11, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img11, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img11, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img11,(250,225), (320,150), (0,0,255),3)
text1= cv2.putText(img11, "In ML , Feature ",(340,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img11, "engeneering happens Manually.",(170,250),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img11, "People have to extract",(170,270),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img11, "the features manually",(170,290),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img11, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)




cv2.imshow("Black",img11)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img12 = np.zeros((500,500,3), np.int8)

pt1 = (375,100)
pt2 = (350, 130)
pt3 = (400,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (375,225)
pt5= (290,350)
pt6= (460,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img12, (375,125),100,(255,0,0),3)
cir2 = cv2.circle(img12, (330,75),15,(0,0,255),3)
cir3= cv2.circle(img12, (420,75),15,(0,0,255),3)
cir4 = cv2.circle(img12, (330,75),1,(0,255,0),3)
cir5 = cv2.circle(img12, (420,75),1,(0,255,0),3)
hor = cv2.rectangle(img12, (340,155),(400,160),(0,0,255),2)
tri1= cv2.drawContours(img12, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img12, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img12, (320,350),(320,450),(0,0,255),4)
line2= cv2.line(img12, (430,350),(430,450),(0,0,255),4)
line3= cv2.line(img12, (320,450),(300,450),(0,0,255),4)
line4 = cv2.line(img12, (430,450),(410,450),(0,0,255),4)
line5 = cv2.line(img12, (250,230), (370,230), (0,0,255),3)

text1= cv2.putText(img12, "Feature engeneering ",(25,200),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img12, "happens Manually.",(25,220),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img12, "People have to extract",(25,240),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img12, "the features manually.",(25,260),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img12, "Thats why we require",(25,300),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img12, "large amount of data.",(25,320),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img12, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

cv2.imshow("Black",img12)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img13 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img13, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img13, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img13, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img13, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img13, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img13, (90,155),(155,163),(0,0,255),2)
tri1= cv2.drawContours(img13, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img13, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img13, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img13, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img13, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img13, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img13, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img13,(250,225), (320,150), (0,0,255),3)
text1= cv2.putText(img13, "Training time ",(340,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img13, "is less,as i can work",(170,250),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img13, "for small datasets",(170,270),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img12, "the features manually",(170,290),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img13, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)




cv2.imshow("Black",img13)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img14 = np.zeros((500,500,3), np.int8)

cir1 = cv2.circle(img14, (90,90),60,(255,0,0),3)
# cir2 = cv2.circle(img6, (80,75),15,(0,0,255),3)
# cir3= cv2.circle(img6, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img14, (65,67),4,(0,255,0),2)
cir5 = cv2.circle(img14, (130,67),4,(0,255,0),2)
# # hor = cv2.rectangle(img6, (90,155),(155,163),(0,0,255),3)
cir6 = cv2.circle(img14, (125,250),100,(255,0,0),3)



line1 = cv2.line(img14, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img14, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img14, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img14, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img14, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img6,(250,225), (250,80), (0,0,255),3)
# line7 = cv2.line(img6, (250,80), (200,60), (0,0,255),3)

text = cv2.putText(img14, "Training time is high,", (260,250),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text = cv2.putText(img14, "As feature extraction", (260,270),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text = cv2.putText(img14, "happens automatically.", (260,290),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text =cv2.putText(img14, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

pt1 = (90,80)
pt2 = (80, 100)
pt3 = (110,100)
triangle_cnt = np.array( [pt1, pt2, pt3] )

tri2= cv2.drawContours(img14, [triangle_cnt], 0, (0,255,0), -1)


cv2.imshow("Black",img14)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img14 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


# cir1 = cv2.circle(img14, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img14, (80,80),15,(0,0,255),3)
cir3= cv2.circle(img14, (172,80),15,(0,0,255),3)
cir4 = cv2.circle(img14, (80,80),1,(0,255,0),3)
cir5 = cv2.circle(img14, (172,80),1,(0,255,0),3)
hor = cv2.rectangle(img14, (90,155),(155,165),(0,0,255),2)
tri1= cv2.drawContours(img14, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img14, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img14, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img14, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img14, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img14, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img14, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img14,(250,225), (330,320), (0,0,255),3)
text1= cv2.putText(img14, "I use statistical",(250,190),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img14, "methods to find out ",(270,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img14, "the relationships.",(290,270),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img14, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

hor=cv2.rectangle(img14,(55,50),(200,227),(0,0,255),2)


cv2.imshow("Black",img14)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img15 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


# cir1 = cv2.circle(img14, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img15, (80,80),15,(0,0,255),3)
cir3= cv2.circle(img15, (172,80),15,(0,0,255),3)
cir4 = cv2.circle(img15, (80,80),1,(0,255,0),3)
cir5 = cv2.circle(img15, (172,80),1,(0,255,0),3)
hor = cv2.rectangle(img15, (90,155),(155,165),(0,0,255),2)
tri1= cv2.drawContours(img15, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img15, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img15, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img15, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img15, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img15, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img15, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img15,(250,225), (330,320), (0,0,255),3)
text1= cv2.putText(img15, "I use a logical network",(250,190),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img15, "called as  ",(270,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img15, " nueral networks.",(290,270),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img15, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

hor=cv2.rectangle(img15,(55,50),(200,227),(0,0,255),2)


cv2.imshow("Black",img15)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img16 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img16, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img16, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img16, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img16, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img16, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img16, (90,155),(155,163),(0,0,255),2)
tri1= cv2.drawContours(img16, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img16, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img16, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img16, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img16, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img16, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img16, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img16,(250,225), (250,150), (0,0,255),3)
text1= cv2.putText(img16, "I can work on",(250,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img16, "low performance machines.",(235,250),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text2=cv2.putText(img16, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)



cv2.imshow("Black",img16)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img17 = np.zeros((500,500,3), np.int8)

pt1 = (375,100)
pt2 = (350, 130)
pt3 = (400,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (375,225)
pt5= (290,350)
pt6= (460,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img17, (375,125),100,(255,0,0),3)
cir2 = cv2.circle(img17, (330,75),15,(0,0,255),3)
cir3= cv2.circle(img17, (420,75),15,(0,0,255),3)
cir4 = cv2.circle(img17, (330,75),1,(0,255,0),3)
cir5 = cv2.circle(img17, (420,75),1,(0,255,0),3)
hor = cv2.rectangle(img17, (340,155),(400,160),(0,0,255),2)
tri1= cv2.drawContours(img17, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img17, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img17, (320,350),(320,450),(0,0,255),4)
line2= cv2.line(img17, (430,350),(430,450),(0,0,255),4)
line3= cv2.line(img17, (320,450),(300,450),(0,0,255),4)
line4 = cv2.line(img17, (430,450),(410,450),(0,0,255),4)
line5 = cv2.line(img17, (250,230), (370,230), (0,0,255),3)


text1= cv2.putText(img17, "Need high performance",(25,240),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img17, "Machines.",(25,260),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img17, "Like : GPU",(25,300),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text2=cv2.putText(img17, "TPU.",(25,320),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img17, "DL",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

cv2.imshow("Black",img17)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img18 = np.zeros((500,500,3), np.int8)

pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


# cir1 = cv2.circle(img14, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img18, (80,80),15,(0,0,255),3)
cir3= cv2.circle(img18, (172,80),15,(0,0,255),3)
cir4 = cv2.circle(img18, (80,80),1,(0,255,0),3)
cir5 = cv2.circle(img18, (172,80),1,(0,255,0),3)
hor = cv2.rectangle(img18, (90,155),(155,165),(0,0,255),2)
tri1= cv2.drawContours(img18, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img18, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img18, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img18, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img18, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img18, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img18, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img18,(250,225), (330,320), (0,0,255),3)
text1= cv2.putText(img18, "Most of the ",(250,190),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img18, "ML algorithms are ",(270,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text1= cv2.putText(img18, "interpretable.",(290,270),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img18, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

hor=cv2.rectangle(img18,(55,50),(200,227),(255,0,0),2)


cv2.imshow("Black",img18)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img19 = np.zeros((500,500,3), np.int8)

cir1 = cv2.circle(img19, (100,100),60,(255,0,0),3)
# cir2 = cv2.circle(img6, (80,75),15,(0,0,255),3)
# cir3= cv2.circle(img6, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img19, (65,67),4,(0,255,0),2)
cir5 = cv2.circle(img19, (130,67),4,(0,255,0),2)
# # hor = cv2.rectangle(img6, (90,155),(155,163),(0,0,255),3)
cir6 = cv2.circle(img19, (125,250),100,(255,0,0),3)



line1 = cv2.line(img19, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img19, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img19, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img19, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img19, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img6,(250,225), (250,80), (0,0,255),3)
# line7 = cv2.line(img6, (250,80), (200,60), (0,0,255),3)

text = cv2.putText(img19, "DL algorithms are", (300,230),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text = cv2.putText(img19, "not interpretable.", (300,250),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text =cv2.putText(img19, "DL",(300,50),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

pt1 = (90,80)
pt2 = (80, 100)
pt3 = (110,100)
triangle_cnt = np.array( [pt1, pt2, pt3] )

tri2= cv2.drawContours(img19, [triangle_cnt], 0, (0,255,0), -1)


cv2.imshow("Black",img19)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img20 = np.zeros((500,500,3), np.int8)



pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])



cir1 = cv2.circle(img20, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img20, (80,75),15,(0,0,255),3)
cir3= cv2.circle(img20, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img20, (80,75),1,(0,255,0),3)
cir5 = cv2.circle(img20, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img20, (90,155),(155,163),(0,0,255),3)
tri1= cv2.drawContours(img20, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img20, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img20, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img20, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img20, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img20, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img20, (125,225), (250,225), (0,0,255),3)
line6 = cv2.line(img20,(250,225), (250,150), (0,0,255),3)
# text = cv2.putText(img2, "Hello Machine Learning", (250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text =cv2.putText(img20, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)




# cv2.imshow("Black",img2)
# cv2.waitKey()
# cv2.destroyAllWindows()

# img12 = np.zeros((500,500,3), np.int8)

pt1 = (375,100)
pt2 = (350, 130)
pt3 = (400,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (375,225)
pt5= (290,350)
pt6= (460,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img20, (375,125),100,(255,0,0),3)
cir2 = cv2.circle(img20, (330,75),15,(0,0,255),3)
cir3= cv2.circle(img20, (420,75),15,(0,0,255),3)
cir4 = cv2.circle(img20, (330,75),1,(0,255,0),3)
cir5 = cv2.circle(img20, (420,75),1,(0,255,0),3)
hor = cv2.rectangle(img20, (340,155),(400,160),(0,0,255),2)
tri1= cv2.drawContours(img20, [triangle_cnt], 0, (0,255,0), 2)
tri2= cv2.drawContours(img20, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img20, (320,350),(320,450),(0,0,255),4)
line2= cv2.line(img20, (430,350),(430,450),(0,0,255),4)
line3= cv2.line(img20, (320,450),(300,450),(0,0,255),4)
line4 = cv2.line(img20, (430,450),(410,450),(0,0,255),4)
line5 = cv2.line(img20, (250,230), (370,230), (0,0,255),3)

# text1= cv2.putText(img20, "Feature engeneering ",(25,200),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text1= cv2.putText(img20, "happens Manually.",(25,220),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text1= cv2.putText(img20, "People have to extract",(25,240),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img20, "the features manually.",(25,260),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img20, "Thats why we require",(25,300),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img20, "large amount of data.",(25,320),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img20, "DL",(75,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img20, "ML",(425,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text1= cv2.putText(img20, "Ok Ok ! We should not argue, we have to together ",(5,470),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),1)
text1= cv2.putText(img20, "contribute to AI.",(5,490),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),1)

cv2.imshow("Black",img20)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img21 = np.zeros((500,500,3), np.int8)



pt1 = (125,100)
pt2 = (100, 130)
pt3 = (150,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (125,225)
pt5= (35,350)
pt6= (210,350)
triangle_cnt1= np.array([pt4,pt5,pt6])



cir1 = cv2.circle(img21, (125,125),100,(255,0,0),3)
cir2 = cv2.circle(img21, (110,75),15,(0,0,255),3)
cir3= cv2.circle(img21, (172,75),15,(0,0,255),3)
cir4 = cv2.circle(img21, (110,75),1,(0,255,0),3)
cir5 = cv2.circle(img21, (172,75),1,(0,255,0),3)
hor = cv2.rectangle(img21, (90,155),(155,163),(0,0,255),2)
tri1= cv2.drawContours(img21, [triangle_cnt], 0, (0,255,0), -1)
tri2= cv2.drawContours(img21, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img21, (60,350),(60,450),(0,0,255),4)
line2= cv2.line(img21, (180,350),(180,450),(0,0,255),4)
line3= cv2.line(img21, (60,450),(80,450),(0,0,255),4)
line4 = cv2.line(img21, (180,450),(200,450),(0,0,255),4)
line5 = cv2.line(img21, (125,225), (250,225), (0,0,255),3)
# line6 = cv2.line(img21,(250,225), (250,150), (0,0,255),3)
# text = cv2.putText(img2, "Hello Machine Learning", (250,150),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text =cv2.putText(img20, "ML",(125,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)




# cv2.imshow("Black",img2)
# cv2.waitKey()
# cv2.destroyAllWindows()

# img12 = np.zeros((500,500,3), np.int8)

pt1 = (375,100)
pt2 = (350, 130)
pt3 = (400,130)
triangle_cnt = np.array( [pt1, pt2, pt3] )


pt4= (375,225)
pt5= (290,350)
pt6= (460,350)
triangle_cnt1= np.array([pt4,pt5,pt6])


cir1 = cv2.circle(img21, (375,125),100,(255,0,0),3)
cir2 = cv2.circle(img21, (330,75),15,(0,0,255),3)
cir3= cv2.circle(img21, (390,75),15,(0,0,255),3)
cir4 = cv2.circle(img21, (330,75),1,(0,255,0),3)
cir5 = cv2.circle(img21, (390,75),1,(0,255,0),3)
hor = cv2.rectangle(img21, (340,155),(400,160),(0,0,255),2)
tri1= cv2.drawContours(img21, [triangle_cnt], 0, (0,255,0), 2)
tri2= cv2.drawContours(img21, [triangle_cnt1], 0, (0,255,0), -1)
line1 = cv2.line(img21, (320,350),(320,450),(0,0,255),4)
line2= cv2.line(img21, (430,350),(430,450),(0,0,255),4)
line3= cv2.line(img21, (320,450),(300,450),(0,0,255),4)
line4 = cv2.line(img21, (430,450),(410,450),(0,0,255),4)
line5 = cv2.line(img21, (250,230), (370,230), (0,0,255),3)

# text1= cv2.putText(img20, "Feature engeneering ",(25,200),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text1= cv2.putText(img20, "happens Manually.",(25,220),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text1= cv2.putText(img20, "People have to extract",(25,240),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img20, "the features manually.",(25,260),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img20, "Thats why we require",(25,300),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
# text2=cv2.putText(img20, "large amount of data.",(25,320),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


text2=cv2.putText(img21, "DL",(75,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)
text =cv2.putText(img21, "ML",(425,25),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text1= cv2.putText(img21, "BEST FRIENDS FOREVER",(125,470),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),1)
text1= cv2.putText(img21, "Hurray.......!",(125,490),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),1)

cv2.imshow("Black",img21)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img22 = np.zeros((500,500,3), np.int8)
text1= cv2.putText(img22, "Happy ending",(125,125),cv2.FONT_HERSHEY_SIMPLEX,1,(200,255,200),3)


text1= cv2.putText(img22, "Created by :",(125,250),cv2.FONT_HERSHEY_SIMPLEX,0.6,(255,0,200),3)
text1= cv2.putText(img22, "G.Narendhar",(125,300),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text1= cv2.putText(img22, "T.Utteja",(125,320),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

text1= cv2.putText(img22, "A.Deepthi",(125,340),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)


cv2.imshow("Black",img22)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img23 = np.zeros((500,500,3), np.int8)
text1= cv2.putText(img23, "If ML and DL can talk...?",(5,250),cv2.FONT_HERSHEY_SIMPLEX,1.2,(0,25,200),3)
text1= cv2.putText(img23, "Lets have a look how they feel!",(25,340),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,200),2)

cv2.imshow("Black",img23)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
imageio.mimsave(r"C:\Users\hp\Downloads\Data Science Innomatics\DS written notes\Deep_learning\OpenCv_Projects\img.gif", [img23,img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16,img17,img18,img19,img20,img21,img22], fps = 0.5)
# Out:
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int8 to uint8. Range [0, 127]. Convert image to uint8 prior to saving to suppress this warning.
# ...
